# %%
import pandas as pd
import numpy as np
import json
import pprint
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/')
db = client.companies

# %%
german_comps = db.companies.find({
    "offices.country_code": 'DEU'
        })

# %%
euro_comps = pd.DataFrame(german_comps)
euro_comps.head()
# Out:
#                         _id acquisition  \
# 0  52cdef7c4bab8bd675297da8        None
# 1  52cdef7c4bab8bd675297dd7        None
# 2  52cdef7c4bab8bd675297dba        None
# 3  52cdef7c4bab8bd675297e81        None
# 4  52cdef7c4bab8bd675297ecd        None
#
#                                         acquisitions alias_list  \
# 0  [{'price_amount': None, 'price_currency_code':...
# 1                                                 []
# 2  [{'price_amount': 60000000, 'price_currency_co...     Google
# 3  [{'price_amount': 30000000, 'price_currency_co...
# 4                                                 []       None
#
#                                        blog_feed_url  \
# 0
# 1
# 2  http://googleblog.blogspot.com/feeds/posts/def...
# 3          http://blog.brightcove.com/blog/index.rdf
# 4               http://feeds.feedburner.com/jimdo_en
#
#                          blog_url category_code  \
# 0       http://www.openx.com/blog   advertising
# 1                                   games_video
# 2  http://googleblog.blogspot.com        search
# 3     http://blog.brightcove.com/    enterprise
# 4      http://www.jimdo.com/blog/           web
#
#                                         competitions  \
# 0  [{'competitor': {'name': 'DoubleClick', 'perma...
# 1  [{'competitor': {'name': 'Amie Street', 'perma...
# 2  [{'competitor': {'name': 'Technorati', 'permal...
# 3  [{'competitor': {'name': 'PermissionTV', 'perm...
# 4  [{'competitor': {'name': 'Weebly', 'permalink'...
#
#                      created_at                                crunchbase_url  \
# 0  Wed Jun 13 18:23:43 UTC 2007       http://www.crunchbase.com/company/openx
# 1  Wed Jul 04 05:29:56 UTC 2007   http://www.crunchbase.com/company/sellaband
# 2  Sat Jun 30 22:18:12 UTC 2007      http://www.crunchbase.com/company/google
# 3  Thu Aug 02 15:56:57 UTC 2007  http://www.crunchbase.com/company/brightcove
# 4  Wed Aug 15 11:07:35 UTC 2007       http://www.crunchbase.com/company/jimdo
#
#    ...  phone_number                                           products  \
# 0  ...  626-466-1141  [{'name': 'OpenX Enterprise', 'permalink': 'op...
# 1  ...                [{'name': 'SellABand', 'permalink': 'sellaband'}]
# 2  ...  650.253.0000  [{'name': 'Gmail', 'permalink': 'gmail'}, {'na...
# 3  ...  617.500.4947  [{'name': 'Brightcove', 'permalink': 'brightco...
# 4  ...  415-727-0774  [{'name': 'JimdoFree', 'permalink': 'jimdofree...
#
#                                        providerships  \
# 0                                                 []
# 1                                                 []
# 2  [{'title': 'Public Relations (APAC)', 'is_past...
# 3  [{'title': '', 'is_past': False, 'provider': {...
# 4  [{'title': '', 'is_past': False, 'provider': {...
#
#                                        relationships  \
# 0  [{'is_past': False, 'title': 'VP, Engineering ...
# 1  [{'is_past': False, 'title': 'CEO', 'person': ...
# 2  [{'is_past': False, 'title': 'CEO of Google Co...
# 3  [{'is_past': False, 'title': 'CEO', 'person': ...
# 4  [{'is_past': False, 'title': 'Co-founder', 'pe...
#
#                                          screenshots  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'available_sizes': [[[150, 117], 'assets/ima...
#
#                                             tag_list total_money_raised  \
# 0  ad-server, ad-serving, ad-exchange, yield-opti...             $75.5M
# 1                    musicmonetizatoin, music, bands                $5M
# 2  search, gmail, blogger, find, information, you...              $555M
# 3  brightcove, online-video-platform, video, tv-e...              $103M
# 4  jimdo, ajax, siteeditor, websiteeditor, websit...                 $0
#
#    twitter_username                    updated_at  \
# 0             OpenX  Wed Dec 11 00:44:01 UTC 2013
# 1         sellaband  Thu Apr 29 21:39:39 UTC 2010
# 2            google  Mon Jan 06 04:52:54 UTC 2014
# 3        brightcove  Fri Oct 11 19:48:45 UTC 2013
# 4             jimdo  Fri Dec 06 00:22:46 UTC 2013
#
#                                         video_embeds
# 0  [{'embed_code': '<object width="430" height="2...
# 1                                                 []
# 2  [{'embed_code': '<embed src="http://blip.tv/pl...
# 3  [{'embed_code': '<embed src="http://blip.tv/pl...
# 4  [{'embed_code': '<iframe width="430" height="3...
#
# [5 rows x 42 columns]

# %%
less_columns = euro_comps[['name', 'offices', 'funding_rounds', 'total_money_raised', 'founded_year', 'number_of_employees', 'category_code', 'description', 'overview', 'tag_list']].copy()
less_columns.head()
# Out:
#          name                                            offices  \
# 0       OpenX  [{'description': 'Headquarters', 'address1': '...
# 1   SellABand  [{'description': None, 'address1': 'Harderhook...
# 2      Google  [{'description': 'Google Headquarters', 'addre...
# 3  Brightcove  [{'description': 'Headquarters', 'address1': '...
# 4       Jimdo  [{'description': 'Germany', 'address1': 'Stres...
#
#                                       funding_rounds total_money_raised  \
# 0  [{'id': 31, 'round_code': 'a', 'source_url': '...             $75.5M
# 1  [{'id': 1989, 'round_code': 'a', 'source_url':...                $5M
# 2  [{'id': 380, 'round_code': 'angel', 'source_ur...              $555M
# 3  [{'id': 290, 'round_code': 'a', 'source_url': ...              $103M
# 4  [{'id': 352, 'round_code': 'angel', 'source_ur...                 $0
#
#    founded_year  number_of_employees category_code             description  \
# 0        2008.0                305.0   advertising                   OpenX
# 1        2006.0                  NaN   games_video  Fund raising for bands
# 2        1998.0              28000.0        search
# 3        2004.0                220.0    enterprise   Online video platform
# 4        2007.0                170.0           web  online website builder
#
#                                             overview  \
# 0  <p>OpenX is a global leader in digital and mob...
# 1  <p>SellaBand.com first launched in August 2006...
# 2  <p>Google provides search and advertising serv...
# 3  <p>Brightcove Inc. (NASDAQ: BCOV), a leading g...
# 4  <p>Jimdo is the easiest way to create a websit...
#
#                                             tag_list
# 0  ad-server, ad-serving, ad-exchange, yield-opti...
# 1                    musicmonetizatoin, music, bands
# 2  search, gmail, blogger, find, information, you...
# 3  brightcove, online-video-platform, video, tv-e...
# 4  jimdo, ajax, siteeditor, websiteeditor, websit...

# %%
less_columns.shape
# Out:
# (383, 10)

# %%
print(less_columns['offices'][0])
# Out:
# [{'description': 'Headquarters', 'address1': '888 East Walnut Street', 'address2': '', 'zip_code': '91101', 'city': 'Pasadena', 'state_code': 'CA', 'country_code': 'USA', 'latitude': 34.1494713, 'longitude': -118.1327468}, {'description': 'New York', 'address1': '584 Broadway', 'address2': '8th Floor', 'zip_code': '10012', 'city': 'New York', 'state_code': 'NY', 'country_code': 'USA', 'latitude': None, 'longitude': None}, {'description': 'London', 'address1': '1 Maple Place', 'address2': '', 'zip_code': 'W1T 4BB', 'city': 'London', 'state_code': None, 'country_code': 'GBR', 'latitude': None, 'longitude': None}, {'description': 'Tokyo', 'address1': '4-12-25 Minami-Azabu', 'address2': 'Minato-ku', 'zip_code': '1060047', 'city': 'Tokyo', 'state_code': None, 'country_code': 'JPN', 'latitude': None, 'longitude': None}, {'description': 'Munich', 'address1': 'Maximilianstrasse 35a', 'address2': '', 'zip_code': '80539', 'city': 'Munich', 'state_code': None, 'country_code': 'DEU', 'latitude': None, 'longitude': None}]

# %%
def get_coords(less_columns):
    # gets a row from less_columns df and returns the first german office in dict shape
    res = {
        "city": None,
        "lat": None,
        "lng": None,
        "site": None
    }

    oficinas = less_columns['offices']
    
    for oficina in oficinas: 
        
        if oficina.get('country_code') == 'DEU' and oficina.get('latitude') and oficina.get('longitude'): 
            
            coords = {
            "type": "Point",
            "coordinates": [oficina.get('longitude'), oficina.get('latitude')]
            }
            res = {
                "city": oficina.get('city'),
                "lat": oficina.get('latitude'),
                "lng": oficina.get('longitude'),
                "site": coords
                }
            break
    return res

location = less_columns[['offices']].apply(get_coords, result_type='expand', axis=1)
location
# Out:
#               city        lat        lng  \
# 0             None        NaN        NaN
# 1    46395 Bocholt  51.808933   6.553452
# 2          Hamburg  53.554052   9.985266
# 3             None        NaN        NaN
# 4             None        NaN        NaN
# 5           Munich  48.163509  11.558261
# 6             None        NaN        NaN
# 7             None        NaN        NaN
# 8           Berlin  52.501345  13.410907
# 9             None        NaN        NaN
# 10     Norderstedt  53.707739  10.023246
# 11            None        NaN        NaN
# 12          Berlin  52.523402  13.398694
# 13         Hamburg  53.540804   9.993586
# 14            None        NaN        NaN
# 15            None        NaN        NaN
# 16            None        NaN        NaN
# 17         Hamburg  53.555554   9.987930
# 18          Berlin  52.513183  13.394149
# 19          Munich  48.124827  11.556452
# 20         Hamburg  53.545980   9.987181
# 21        Hannover  52.365387   9.758041
# 22          Aachen  50.791481   6.066681
# 23            None        NaN        NaN
# 24          Berlin  52.502633  13.441005
# 25          Berlin  52.498620  13.446903
# 26          Berlin  52.529075  13.416151
# 27      Ostfildern  48.724352   9.222373
# 28          Munich  48.201280  11.546494
# 29            None        NaN        NaN
# ..             ...        ...        ...
# 353        Hamburg  53.550150   9.998620
# 354         Berlin  52.532547  13.408999
# 355      LÃ¼neburg  53.261554  10.418359
# 356           None        NaN        NaN
# 357           None        NaN        NaN
# 358        LÃ¼beck  53.835358  10.697679
# 359         Berlin  52.527926  13.381354
# 360        Hamburg  53.597305   9.976252
# 361           None        NaN        NaN
# 362        Dresden  51.058005  13.768621
# 363        Dresden  51.034362  13.775964
# 364                 48.055441  11.607509
# 365                 48.265012  13.030567
# 366           None        NaN        NaN
# 367        Hamburg  53.554390  10.017753
# 368           None        NaN        NaN
# 369                 48.256468   9.021606
# 370                 48.381895  11.535384
# 371        Dresden  51.126093  13.785032
# 372      Darmstadt  49.897475   8.608451
# 373       Mannheim  49.507710   8.523008
# 374       Montabur  50.433334   7.804888
# 375           None        NaN        NaN
# 376           None        NaN        NaN
# 377      Stuttgart  48.781871   9.177304
# 378           None        NaN        NaN
# 379         Berlin  52.494307  13.434474
# 380           None        NaN        NaN
# 381                 54.771291   9.396214
# 382           Kiel  54.323738  10.166515
#
#                                                   site
# 0                                                 None
# 1    {'type': 'Point', 'coordinates': [6.553452, 51...
# 2    {'type': 'Point', 'coordinates': [9.985266, 53...
# 3                                                 None
# 4                                                 None
# 5    {'type': 'Point', 'coordinates': [11.5582609, ...
# 6                                                 None
# 7                                                 None
# 8    {'type': 'Point', 'coordinates': [13.4109071, ...
# 9                                                 None
# 10   {'type': 'Point', 'coordinates': [10.023246, 5...
# 11                                                None
# 12   {'type': 'Point', 'coordinates': [13.398694, 5...
# 13   {'type': 'Point', 'coordinates': [9.993586, 53...
# 14                                                None
# 15                                                None
# 16                                                None
# 17   {'type': 'Point', 'coordinates': [9.98793, 53....
# 18   {'type': 'Point', 'coordinates': [13.3941489, ...
# 19   {'type': 'Point', 'coordinates': [11.556452, 4...
# 20   {'type': 'Point', 'coordinates': [9.987181, 53...
# 21   {'type': 'Point', 'coordinates': [9.7580413, 5...
# 22   {'type': 'Point', 'coordinates': [6.066681, 50...
# 23                                                None
# 24   {'type': 'Point', 'coordinates': [13.441005, 5...
# 25   {'type': 'Point', 'coordinates': [13.4469031, ...
# 26   {'type': 'Point', 'coordinates': [13.4161514, ...
# 27   {'type': 'Point', 'coordinates': [9.2223731, 4...
# 28   {'type': 'Point', 'coordinates': [11.546494, 4...
# 29                                                None
# ..                                                 ...
# 353  {'type': 'Point', 'coordinates': [9.99862, 53....
# 354  {'type': 'Point', 'coordinates': [13.4089986, ...
# 355  {'type': 'Point', 'coordinates': [10.4183586, ...
# 356                                               None
# 357                                               None
# 358  {'type': 'Point', 'coordinates': [10.6976787, ...
# 359  {'type': 'Point', 'coordinates': [13.3813542, ...
# 360  {'type': 'Point', 'coordinates': [9.9762519, 5...
# 361                                               None
# 362  {'type': 'Point', 'coordinates': [13.7686212, ...
# 363  {'type': 'Point', 'coordinates': [13.7759644, ...
# 364  {'type': 'Point', 'coordinates': [11.6075086, ...
# 365  {'type': 'Point', 'coordinates': [13.0305666, ...
# 366                                               None
# 367  {'type': 'Point', 'coordinates': [10.0177531, ...
# 368                                               None
# 369  {'type': 'Point', 'coordinates': [9.0216057, 4...
# 370  {'type': 'Point', 'coordinates': [11.5353842, ...
# 371  {'type': 'Point', 'coordinates': [13.7850316, ...
# 372  {'type': 'Point', 'coordinates': [8.6084515, 4...
# 373  {'type': 'Point', 'coordinates': [8.5230082, 4...
# 374  {'type': 'Point', 'coordinates': [7.8048883, 5...
# 375                                               None
# 376                                               None
# 377  {'type': 'Point', 'coordinates': [9.1773043, 4...
# 378                                               None
# 379  {'type': 'Point', 'coordinates': [13.434474, 5...
# 380                                               None
# 381  {'type': 'Point', 'coordinates': [9.3962136, 5...
# 382  {'type': 'Point', 'coordinates': [10.1665152, ...
#
# [383 rows x 4 columns]

# %%
germany = pd.concat([less_columns,location], axis=1)[["name","city","offices","site","lat","lng","total_money_raised","founded_year","number_of_employees","category_code","description","overview","tag_list"]]
germany
# Out:
#                  name           city  \
# 0               OpenX           None
# 1           SellABand  46395 Bocholt
# 2              Google        Hamburg
# 3          Brightcove           None
# 4               Jimdo           None
# 5         Adknowledge         Munich
# 6            PubMatic           None
# 7       Jive Software           None
# 8               headr         Berlin
# 9          ValueClick           None
# 10              alluc    Norderstedt
# 11             tyntec           None
# 12             Plazes         Berlin
# 13     MyNeighborhood        Hamburg
# 14             Twenga           None
# 15             Smaato           None
# 16             Criteo           None
# 17               XING        Hamburg
# 18          GameDuell         Berlin
# 19            amiando         Munich
# 20               Qype        Hamburg
# 21         openPeople       Hannover
# 22            iOpener         Aachen
# 23     Opera Software           None
# 24               Qiro         Berlin
# 25          99designs         Berlin
# 26    VZnet Netzwerke         Berlin
# 27             doXtop     Ostfildern
# 28            Moconso         Munich
# 29            Topicle           None
# ..                ...            ...
# 353           apprupt        Hamburg
# 354            Idealo         Berlin
# 355         Comparado      LÃ¼neburg
# 356  PIERIS Proteolab           None
# 357       pluriSelect           None
# 358         Microstim        LÃ¼beck
# 359          Webtrekk         Berlin
# 360          Bigpoint        Hamburg
# 361           Daimler           None
# 362           sim4tec        Dresden
# 363          ubigrate        Dresden
# 364      Clean Mobile
# 365   ISIS sentronics
# 366       Readspeaker           None
# 367      jogmap media        Hamburg
# 368         Cogniance           None
# 369       Centrotherm
# 370          GP Solar
# 371         HiperScan        Dresden
# 372        Liquiverse      Darmstadt
# 373           Pro2col       Mannheim
# 374   United Internet       Montabur
# 375      AdLINK Group           None
# 376             Avira           None
# 377         BizSphere      Stuttgart
# 378          Sevenval           None
# 379          Sauspiel         Berlin
# 380          Sovicell           None
# 381         Metasonic
# 382        AwardSpace           Kiel
#
#                                                offices  \
# 0    [{'description': 'Headquarters', 'address1': '...
# 1    [{'description': None, 'address1': 'Harderhook...
# 2    [{'description': 'Google Headquarters', 'addre...
# 3    [{'description': 'Headquarters', 'address1': '...
# 4    [{'description': 'Germany', 'address1': 'Stres...
# 5    [{'description': 'World Headquarters', 'addres...
# 6    [{'description': 'HQ', 'address1': '305 Main S...
# 7    [{'description': 'Palo Alto HQ', 'address1': '...
# 8    [{'description': '', 'address1': 'Ritterstr. 1...
# 9    [{'description': None, 'address1': None, 'addr...
# 10   [{'description': '', 'address1': 'Stormarnstra...
# 11   [{'description': 'UK, London', 'address1': '6 ...
# 12   [{'description': None, 'address1': 'Monbijoupl...
# 13   [{'description': None, 'address1': 'Grosser Gr...
# 14   [{'description': 'Paris Office', 'address1': '...
# 15   [{'description': '', 'address1': '240 Stockton...
# 16   [{'description': 'Headquarters', 'address1': '...
# 17   [{'description': 'XING AG', 'address1': 'Dammt...
# 18   [{'description': 'US Headquarters', 'address1'...
# 19   [{'description': '', 'address1': 'Sandstrasse ...
# 20   [{'description': 'HQ', 'address1': 'Großer Bur...
# 21   [{'description': '', 'address1': 'Stolzestr. 4...
# 22   [{'description': None, 'address1': 'Roermonder...
# 23   [{'description': 'Headquarters', 'address1': '...
# 24   [{'description': '', 'address1': 'Pfuelstraße ...
# 25   [{'description': 'United States (HQ)', 'addres...
# 26   [{'description': '', 'address1': 'Saarbrücker ...
# 27   [{'description': 'Coextant Systems', 'address1...
# 28   [{'description': None, 'address1': 'Waldmeiste...
# 29   [{'description': None, 'address1': 'Zoolium Gm...
# ..                                                 ...
# 353  [{'description': '', 'address1': 'Speersort 10...
# 354  [{'description': 'Berlin Office', 'address1': ...
# 355  [{'description': 'LÃ¼neburg Office', 'address1...
# 356  [{'description': '', 'address1': 'Lise-Meitner...
# 357  [{'description': 'HQ', 'address1': 'Interdiszi...
# 358  [{'description': '', 'address1': 'Maria-Goeppe...
# 359  [{'description': 'World Headquarters', 'addres...
# 360  [{'description': 'Bigpoint Headquarters', 'add...
# 361  [{'description': 'HQ', 'address1': 'Mercedesst...
# 362  [{'description': '', 'address1': 'Arnoldstr. 1...
# 363  [{'description': '', 'address1': 'Herkulesstr....
# 364  [{'description': '', 'address1': 'Inselkammers...
# 365  [{'description': '', 'address1': 'InnstraÃŸe 2...
# 366  [{'description': '', 'address1': 'Dolderseweg ...
# 367  [{'description': 'jogmap HQ', 'address1': 'Lin...
# 368  [{'description': 'US Headquarters', 'address1'...
# 369  [{'description': '', 'address1': 'Johannes-Sch...
# 370  [{'description': 'Headquarter', 'address1': 'T...
# 371  [{'description': '', 'address1': 'Maria-Reiche...
# 372  [{'description': '', 'address1': 'Goethestrass...
# 373  [{'description': 'Pro2col Head Office', 'addre...
# 374  [{'description': 'HQ', 'address1': 'Elgendorfe...
# 375  [{'description': 'AdLINK Internet Media AG', '...
# 376  [{'description': '', 'address1': 'Kaplaneiweg ...
# 377  [{'description': 'Stuttgart Headquarters', 'ad...
# 378  [{'description': 'Uk,Cologne,Austria', 'addres...
# 379  [{'description': 'Berlin Office', 'address1': ...
# 380  [{'description': '', 'address1': 'Deutscher Pl...
# 381  [{'description': '', 'address1': 'Lilienthalst...
# 382  [{'description': 'World Headquarter', 'address...
#
#                                                   site        lat        lng  \
# 0                                                 None        NaN        NaN
# 1    {'type': 'Point', 'coordinates': [6.553452, 51...  51.808933   6.553452
# 2    {'type': 'Point', 'coordinates': [9.985266, 53...  53.554052   9.985266
# 3                                                 None        NaN        NaN
# 4                                                 None        NaN        NaN
# 5    {'type': 'Point', 'coordinates': [11.5582609, ...  48.163509  11.558261
# 6                                                 None        NaN        NaN
# 7                                                 None        NaN        NaN
# 8    {'type': 'Point', 'coordinates': [13.4109071, ...  52.501345  13.410907
# 9                                                 None        NaN        NaN
# 10   {'type': 'Point', 'coordinates': [10.023246, 5...  53.707739  10.023246
# 11                                                None        NaN        NaN
# 12   {'type': 'Point', 'coordinates': [13.398694, 5...  52.523402  13.398694
# 13   {'type': 'Point', 'coordinates': [9.993586, 53...  53.540804   9.993586
# 14                                                None        NaN        NaN
# 15                                                None        NaN        NaN
# 16                                                None        NaN        NaN
# 17   {'type': 'Point', 'coordinates': [9.98793, 53....  53.555554   9.987930
# 18   {'type': 'Point', 'coordinates': [13.3941489, ...  52.513183  13.394149
# 19   {'type': 'Point', 'coordinates': [11.556452, 4...  48.124827  11.556452
# 20   {'type': 'Point', 'coordinates': [9.987181, 53...  53.545980   9.987181
# 21   {'type': 'Point', 'coordinates': [9.7580413, 5...  52.365387   9.758041
# 22   {'type': 'Point', 'coordinates': [6.066681, 50...  50.791481   6.066681
# 23                                                None        NaN        NaN
# 24   {'type': 'Point', 'coordinates': [13.441005, 5...  52.502633  13.441005
# 25   {'type': 'Point', 'coordinates': [13.4469031, ...  52.498620  13.446903
# 26   {'type': 'Point', 'coordinates': [13.4161514, ...  52.529075  13.416151
# 27   {'type': 'Point', 'coordinates': [9.2223731, 4...  48.724352   9.222373
# 28   {'type': 'Point', 'coordinates': [11.546494, 4...  48.201280  11.546494
# 29                                                None        NaN        NaN
# ..                                                 ...        ...        ...
# 353  {'type': 'Point', 'coordinates': [9.99862, 53....  53.550150   9.998620
# 354  {'type': 'Point', 'coordinates': [13.4089986, ...  52.532547  13.408999
# 355  {'type': 'Point', 'coordinates': [10.4183586, ...  53.261554  10.418359
# 356                                               None        NaN        NaN
# 357                                               None        NaN        NaN
# 358  {'type': 'Point', 'coordinates': [10.6976787, ...  53.835358  10.697679
# 359  {'type': 'Point', 'coordinates': [13.3813542, ...  52.527926  13.381354
# 360  {'type': 'Point', 'coordinates': [9.9762519, 5...  53.597305   9.976252
# 361                                               None        NaN        NaN
# 362  {'type': 'Point', 'coordinates': [13.7686212, ...  51.058005  13.768621
# 363  {'type': 'Point', 'coordinates': [13.7759644, ...  51.034362  13.775964
# 364  {'type': 'Point', 'coordinates': [11.6075086, ...  48.055441  11.607509
# 365  {'type': 'Point', 'coordinates': [13.0305666, ...  48.265012  13.030567
# 366                                               None        NaN        NaN
# 367  {'type': 'Point', 'coordinates': [10.0177531, ...  53.554390  10.017753
# 368                                               None        NaN        NaN
# 369  {'type': 'Point', 'coordinates': [9.0216057, 4...  48.256468   9.021606
# 370  {'type': 'Point', 'coordinates': [11.5353842, ...  48.381895  11.535384
# 371  {'type': 'Point', 'coordinates': [13.7850316, ...  51.126093  13.785032
# 372  {'type': 'Point', 'coordinates': [8.6084515, 4...  49.897475   8.608451
# 373  {'type': 'Point', 'coordinates': [8.5230082, 4...  49.507710   8.523008
# 374  {'type': 'Point', 'coordinates': [7.8048883, 5...  50.433334   7.804888
# 375                                               None        NaN        NaN
# 376                                               None        NaN        NaN
# 377  {'type': 'Point', 'coordinates': [9.1773043, 4...  48.781871   9.177304
# 378                                               None        NaN        NaN
# 379  {'type': 'Point', 'coordinates': [13.434474, 5...  52.494307  13.434474
# 380                                               None        NaN        NaN
# 381  {'type': 'Point', 'coordinates': [9.3962136, 5...  54.771291   9.396214
# 382  {'type': 'Point', 'coordinates': [10.1665152, ...  54.323738  10.166515
#
#     total_money_raised  founded_year  number_of_employees    category_code  \
# 0               $75.5M        2008.0                305.0      advertising
# 1                  $5M        2006.0                  NaN      games_video
# 2                $555M        1998.0              28000.0           search
# 3                $103M        2004.0                220.0       enterprise
# 4                   $0        2007.0                170.0              web
# 5                $248M        2004.0                300.0      advertising
# 6                 $63M        2006.0                380.0      advertising
# 7               $69.4M        2001.0                 50.0         software
# 8                   $0        2012.0                  8.0              web
# 9                 $45M        1998.0               1112.0      advertising
# 10                  $0        2009.0                  7.0      games_video
# 11                  $0        2002.0                150.0           mobile
# 12               €3.7M        2006.0                 15.0              web
# 13                  $0        2007.0                  3.0              web
# 14               €2.6M        2006.0                  NaN        ecommerce
# 15                $18M        2005.0                 95.0      advertising
# 16              $63.4M        2005.0                700.0      advertising
# 17               €5.7M        2003.0                500.0  network_hosting
# 18              $17.5M        2003.0                200.0      games_video
# 19                  $0        2006.0                 76.0              web
# 20              £14.5M        2005.0                  NaN              web
# 21               €200k        2006.0                  5.0              web
# 22              €10.1M           NaN                  NaN      games_video
# 23              $13.2M        1995.0                  NaN         software
# 24                  $0        2006.0                 15.0           mobile
# 25                $35M        2008.0                100.0           design
# 26                  $0        2005.0                300.0              web
# 27                  $0        2007.0                  5.0         software
# 28                  $0           NaN                  NaN             None
# 29                  $0           NaN                  2.0           search
# ..                 ...           ...                  ...              ...
# 353                 $0        2008.0                  NaN      advertising
# 354                 $0        2001.0                200.0        ecommerce
# 355                 $0        2004.0                 40.0              web
# 356             $45.9M        2001.0                  NaN          biotech
# 357              $780k           NaN                  NaN          biotech
# 358             $2.64M        2007.0                  NaN          biotech
# 359                €1M        2003.0                 25.0      advertising
# 360              €420M        2002.0                500.0      games_video
# 361                 $0           NaN                  NaN             None
# 362                 $0           NaN                  NaN         software
# 363              €500k        2008.0                 12.0         software
# 364              €3.3M        2006.0                  NaN        cleantech
# 365             $2.71M        2006.0                  NaN         hardware
# 366                 $0        1999.0                  NaN         software
# 367                 $0        2006.0                  3.0              web
# 368                 $0        2008.0                300.0         software
# 369                 $0           NaN                  NaN             None
# 370                 $0        1999.0                  NaN             None
# 371             $1.11M        2006.0                  NaN            other
# 372              €500k           NaN                  NaN         software
# 373                 $0        2003.0                  9.0         software
# 374                 $0           NaN               5000.0  network_hosting
# 375                 $0        1995.0                  NaN      advertising
# 376                 $0        1988.0                500.0         security
# 377                 $0        2007.0                 25.0       enterprise
# 378                 $0        1999.0                 60.0           mobile
# 379                 $0        2007.0                  8.0      games_video
# 380             $1.19M           NaN                  NaN          biotech
# 381                 $0           NaN                  NaN         software
# 382                 $0        2004.0                 35.0  network_hosting
#
#                                   description  \
# 0                                       OpenX
# 1                      Fund raising for bands
# 2
# 3                       Online video platform
# 4                      online website builder
# 5
# 6                          Sell-Side Platform
# 7                    Social Business Software
# 8               Free Facebook video chat app.
# 9
# 10
# 11        Mobile interaction service provider
# 12               Location Based Microblogging
# 13                                       None
# 14   Shopping search & price comparison sites
# 15                     Mobile RTB Ad Exchange
# 16                        Expand Your Search
# 17
# 18                        Casual Online Games
# 19                  Online Event Registration
# 20    Location-based reviews, recommendations
# 21
# 22                                       None
# 23                           Browser Software
# 24                                       None
# 25          Online graphic design marketplace
# 26                      German Social Network
# 27            Free social publishing services
# 28                                       None
# 29                                       None
# ..                                        ...
# 353                 Mobile Advertising Expert
# 354         International Comparison Shopping
# 355       German Comparison Shopping Platform
# 356                         Biopharmaceutical
# 357               cell and protein separation
# 358                                  implants
# 359                      Online Web Analytics
# 360    developer and provider of online games
# 361                        automotive company
# 362
# 363              modular integration software
# 364            Electric Drive Trains for LEVs
# 365                Optical Sensor Technololgy
# 366                     Online Text to Speech
# 367                Social network for runners
# 368              Software Development Partner
# 369
# 370
# 371
# 372
# 373                    File Transfer Software
# 374          German Internet Service Provider
# 375                          Online Marketing
# 376                        Antivirus software
# 377    Sales Enablement, KM & RIA development
# 378       multi channel technology specialist
# 379     Schafkopf Community (German Cardgame)
# 380                 Blood to Brain Absorbtion
# 381
# 382                      Web Hosting Services
#
#                                               overview  \
# 0    <p>OpenX is a global leader in digital and mob...
# 1    <p>SellaBand.com first launched in August 2006...
# 2    <p>Google provides search and advertising serv...
# 3    <p>Brightcove Inc. (NASDAQ: BCOV), a leading g...
# 4    <p>Jimdo is the easiest way to create a websit...
# 5    <p>Adknowledge is a digital marketing company ...
# 6    <p>Since 2006, PubMatic (www.PubMatic.com) has...
# 7    <p>Jive is the largest and fastest growing ind...
# 8    <p><a href="http://vive.me/" title="vive" rel=...
# 9    <p>ValueClick, Inc. (NASDAQ: VCLK) is one of t...
# 10   <p>alluc.org hosts a database of links to vide...
# 11   <p>tyntec is a global SMS &amp; mobile interac...
# 12   <p>Plazes allows you to find out what others a...
# 13   <p>MyNeighborhood is a local social network wi...
# 14   <p>Twenga, the new-generation search engine, e...
# 15   <p>Smaato&#8217;s SMX platform is the leading ...
# 16   <p>Criteo  is  the  global  leader  in  Perfor...
# 17   <p>XING is the social network for business pro...
# 18   <p>GameDuell – Bringing people together to hav...
# 19   <p>amiando is a pioneer in online event regist...
# 20   <p>Founded in 2006 by German entrepreneur, Ste...
# 21   <p>openPeople is a social networking community...
# 22   <p>iOpener provides and facilitates Real-time ...
# 23   <p>Norway-based Opera provides web browsers fo...
# 24   <p>Qiro GmbH runs the mobile &amp; online comm...
# 25   <p>99designs is the world&#8217;s largest onli...
# 26   <p>Studivz.net is very similar to <a href="/co...
# 27   <p>doXtop is a state-of-the-art Web-publishing...
# 28   <p>Moconso connects companies with mobile serv...
# 29   <p>Topicle allows users to create vertical sea...
# ..                                                 ...
# 353  <p>apprupt is the mobile advertising expert fo...
# 354  <p>The Idealo Internet GmbH, located in Berlin...
# 355  <p>The German price comparison site &#8220;Pre...
# 356  <p>Pieris was established in 2001 with the vis...
# 357  <p>The pluriSelect GmbH located in Leipzig, Ge...
# 358  <p>Microstim GmbH develops a tissue and functi...
# 359  <p>WebtrekkÂ´s Q3 web analytics solution enabl...
# 360  <p>Bigpoint.com is the biggest game portal in ...
# 361  <p>Daimler AG is one of the world&#8217;s most...
# 362  <p>sim4tec provides comprehensive simulation s...
# 363  <p>ubigrate is specialised powerful integratio...
# 364  <p>Clean Mobile AG was founded in 2006 by the ...
# 365  <p>ISIS sentronics GmbH, which creates industr...
# 366  <p>ReadSpeaker speech-enables online content o...
# 367  <p>jogmap is a German  online community for ru...
# 368  <p>Cogniance is a leading software development...
# 369  <p>Centrotherm photovoltaics provides its cust...
# 370  <p>GP Solar GmbH is decisively involved in the...
# 371  <p>HiperScan is the expert in light scanning t...
# 372  <p>Liquiverse is a young software company edit...
# 373  <p>Pro2col specialise in the supply and integr...
# 374  <p>United Internet AG is a German Internet ser...
# 375  <p>The AdLINK Group is a leading European supp...
# 376  <p>Avira, a company with around 100 million cu...
# 377  <p>BizSphere AG is a software and consulting c...
# 378  <p>Sevenval enables the multi channel output o...
# 379  <p>Sauspiel is the largest web community aroun...
# 380  <p>Sovicell is dedicated to providing trusted ...
# 381  <p>Metasonic (formerly jCOM1) was set up in 19...
# 382  <p>AwardSpace is a Web Hosting Company offerin...
#
#                                               tag_list
# 0    ad-server, ad-serving, ad-exchange, yield-opti...
# 1                      musicmonetizatoin, music, bands
# 2    search, gmail, blogger, find, information, you...
# 3    brightcove, online-video-platform, video, tv-e...
# 4    jimdo, ajax, siteeditor, websiteeditor, websit...
# 5    advertising, cpc, adstation, cubics, bidsystem...
# 6                              pubmatic, advertisement
# 7    jivesoftware, clearspace, collaborationsoftwar...
# 8
# 9
# 10                        video, piracy, videodatabase
# 11   mobile-service, mobile-messaging, sms, messagi...
# 12   places, maps, social, community, location, geo...
# 13                                                None
# 14   ecommerce, price-comparison, onlineshopping, s...
# 15   mobileadvertising, mobileapplications, cellpho...
# 16   personalized-retargeting, retargeting, remarke...
# 17   socialnetworking, contacts, professionalnetwor...
# 18   games, social, cross-platform, berlin, fun, go...
# 19   events, event-community, , ticketing, event-re...
# 20
# 21
# 22
# 23
# 24
# 25   graphic-design, crowdsourcing, online-marketpl...
# 26         socialnetwork, germany, berlin, holtzbrinck
# 27   publishing, social-publishing, publishing-hous...
# 28                                                None
# 29                search, verticalsearch, customsearch
# ..                                                 ...
# 353
# 354  comparison, shopping, flights, travel, electro...
# 355  comparison-shopping, product-reviews, preisver...
# 356
# 357
# 358
# 359  online-analytics, optimization, real-time-anal...
# 360  online-games, browser-games, browsergames, bro...
# 361                                               None
# 362
# 363
# 364
# 365
# 366  text-to-speech, speech-as-a-service, accessibl...
# 367        jogging, running, community, social-network
# 368
# 369
# 370                                               None
# 371
# 372
# 373  managed-file-transfer, large-file-transfer, fa...
# 374  germany, isp, internet-service-providers, hosting
# 375              germany, advertising, united-internet
# 376  antivirus, antivir, free-av, security, windows...
# 377  sales, marketing, sales-enablement, knowledge-...
# 378  multi-channel, internet-portals, web-applicati...
# 379  schafkopf, online-schafkopf, gaming, community...
# 380
# 381
# 382  free-webhosting, webhosting, vps, dedicated-se...
#
# [383 rows x 13 columns]

# %%
germany.dropna(subset=['lat'], inplace=True)
germany
# Out:
#                                 name               city  \
# 1                          SellABand      46395 Bocholt
# 2                             Google            Hamburg
# 5                        Adknowledge             Munich
# 8                              headr             Berlin
# 10                             alluc        Norderstedt
# 12                            Plazes             Berlin
# 13                    MyNeighborhood            Hamburg
# 17                              XING            Hamburg
# 18                         GameDuell             Berlin
# 19                           amiando             Munich
# 20                              Qype            Hamburg
# 21                        openPeople           Hannover
# 22                           iOpener             Aachen
# 24                              Qiro             Berlin
# 25                         99designs             Berlin
# 26                   VZnet Netzwerke             Berlin
# 27                            doXtop         Ostfildern
# 28                           Moconso             Munich
# 31                            ADTECH           Dreieich
# 32                               SAP           Walldorf
# 33                        Buongiorno             Berlin
# 34                             acomo             Berlin
# 36                iliketotallyloveit             Berlin
# 38                              YiGG           Weinheim
# 40                            babbel             Berlin
# 43                         Zankapfel             Munich
# 44                        Metaversum             Berlin
# 45                         Undertone            Hamburg
# 46                             Asaph        BÃ¼ttelborn
# 48                          andUNITE             Munich
# ..                               ...                ...
# 339                     FindandSmile          Karlsruhe
# 340                              P21             Munich
# 341               InterMed Discovery
# 343  Organica Feinchemie GmbH Wolfen  Bitterfeld-Wolfen
# 344                  GRIN Publishing             Munich
# 347                itcampus web2test            Leipzig
# 348                       youserbase          Oldenburg
# 349                       Moviepilot             Berlin
# 352                         Springer             Berlin
# 353                          apprupt            Hamburg
# 354                           Idealo             Berlin
# 355                        Comparado          LÃ¼neburg
# 358                        Microstim            LÃ¼beck
# 359                         Webtrekk             Berlin
# 360                         Bigpoint            Hamburg
# 362                          sim4tec            Dresden
# 363                         ubigrate            Dresden
# 364                     Clean Mobile
# 365                  ISIS sentronics
# 367                     jogmap media            Hamburg
# 369                      Centrotherm
# 370                         GP Solar
# 371                        HiperScan            Dresden
# 372                       Liquiverse          Darmstadt
# 373                          Pro2col           Mannheim
# 374                  United Internet           Montabur
# 377                        BizSphere          Stuttgart
# 379                         Sauspiel             Berlin
# 381                        Metasonic
# 382                       AwardSpace               Kiel
#
#                                                offices  \
# 1    [{'description': None, 'address1': 'Harderhook...
# 2    [{'description': 'Google Headquarters', 'addre...
# 5    [{'description': 'World Headquarters', 'addres...
# 8    [{'description': '', 'address1': 'Ritterstr. 1...
# 10   [{'description': '', 'address1': 'Stormarnstra...
# 12   [{'description': None, 'address1': 'Monbijoupl...
# 13   [{'description': None, 'address1': 'Grosser Gr...
# 17   [{'description': 'XING AG', 'address1': 'Dammt...
# 18   [{'description': 'US Headquarters', 'address1'...
# 19   [{'description': '', 'address1': 'Sandstrasse ...
# 20   [{'description': 'HQ', 'address1': 'Großer Bur...
# 21   [{'description': '', 'address1': 'Stolzestr. 4...
# 22   [{'description': None, 'address1': 'Roermonder...
# 24   [{'description': '', 'address1': 'Pfuelstraße ...
# 25   [{'description': 'United States (HQ)', 'addres...
# 26   [{'description': '', 'address1': 'Saarbrücker ...
# 27   [{'description': 'Coextant Systems', 'address1...
# 28   [{'description': None, 'address1': 'Waldmeiste...
# 31   [{'description': 'ADTECH AG', 'address1': 'Rob...
# 32   [{'description': 'World HQ', 'address1': '3475...
# 33   [{'description': '', 'address1': 'Via Cosimo d...
# 34   [{'description': None, 'address1': 'Alt-Moabit...
# 36   [{'description': 'Head Office', 'address1': 'K...
# 38   [{'description': 'yigg HQ', 'address1': 'Schul...
# 40   [{'description': 'Lesson Nine GmbH', 'address1...
# 43   [{'description': '', 'address1': 'Thalkirchner...
# 44   [{'description': None, 'address1': 'Rungestras...
# 45   [{'description': 'NY - Headquarters', 'address...
# 46   [{'description': '', 'address1': 'Am Vogelange...
# 48   [{'description': None, 'address1': 'Leopoldstr...
# ..                                                 ...
# 339  [{'description': '705 West GmbH', 'address1': ...
# 340  [{'description': '', 'address1': 'Eugen-SÃ¤nge...
# 341  [{'description': '', 'address1': 'Otto-Hahn-St...
# 343  [{'description': 'Head office', 'address1': 'K...
# 344  [{'description': 'Headoffice Munich', 'address...
# 347  [{'description': 'head office', 'address1': 'N...
# 348  [{'description': 'Headquarters', 'address1': '...
# 349  [{'description': 'German Headquarters', 'addre...
# 352  [{'description': '', 'address1': 'Heidelberger...
# 353  [{'description': '', 'address1': 'Speersort 10...
# 354  [{'description': 'Berlin Office', 'address1': ...
# 355  [{'description': 'LÃ¼neburg Office', 'address1...
# 358  [{'description': '', 'address1': 'Maria-Goeppe...
# 359  [{'description': 'World Headquarters', 'addres...
# 360  [{'description': 'Bigpoint Headquarters', 'add...
# 362  [{'description': '', 'address1': 'Arnoldstr. 1...
# 363  [{'description': '', 'address1': 'Herkulesstr....
# 364  [{'description': '', 'address1': 'Inselkammers...
# 365  [{'description': '', 'address1': 'InnstraÃŸe 2...
# 367  [{'description': 'jogmap HQ', 'address1': 'Lin...
# 369  [{'description': '', 'address1': 'Johannes-Sch...
# 370  [{'description': 'Headquarter', 'address1': 'T...
# 371  [{'description': '', 'address1': 'Maria-Reiche...
# 372  [{'description': '', 'address1': 'Goethestrass...
# 373  [{'description': 'Pro2col Head Office', 'addre...
# 374  [{'description': 'HQ', 'address1': 'Elgendorfe...
# 377  [{'description': 'Stuttgart Headquarters', 'ad...
# 379  [{'description': 'Berlin Office', 'address1': ...
# 381  [{'description': '', 'address1': 'Lilienthalst...
# 382  [{'description': 'World Headquarter', 'address...
#
#                                                   site        lat         lng  \
# 1    {'type': 'Point', 'coordinates': [6.553452, 51...  51.808933    6.553452
# 2    {'type': 'Point', 'coordinates': [9.985266, 53...  53.554052    9.985266
# 5    {'type': 'Point', 'coordinates': [11.5582609, ...  48.163509   11.558261
# 8    {'type': 'Point', 'coordinates': [13.4109071, ...  52.501345   13.410907
# 10   {'type': 'Point', 'coordinates': [10.023246, 5...  53.707739   10.023246
# 12   {'type': 'Point', 'coordinates': [13.398694, 5...  52.523402   13.398694
# 13   {'type': 'Point', 'coordinates': [9.993586, 53...  53.540804    9.993586
# 17   {'type': 'Point', 'coordinates': [9.98793, 53....  53.555554    9.987930
# 18   {'type': 'Point', 'coordinates': [13.3941489, ...  52.513183   13.394149
# 19   {'type': 'Point', 'coordinates': [11.556452, 4...  48.124827   11.556452
# 20   {'type': 'Point', 'coordinates': [9.987181, 53...  53.545980    9.987181
# 21   {'type': 'Point', 'coordinates': [9.7580413, 5...  52.365387    9.758041
# 22   {'type': 'Point', 'coordinates': [6.066681, 50...  50.791481    6.066681
# 24   {'type': 'Point', 'coordinates': [13.441005, 5...  52.502633   13.441005
# 25   {'type': 'Point', 'coordinates': [13.4469031, ...  52.498620   13.446903
# 26   {'type': 'Point', 'coordinates': [13.4161514, ...  52.529075   13.416151
# 27   {'type': 'Point', 'coordinates': [9.2223731, 4...  48.724352    9.222373
# 28   {'type': 'Point', 'coordinates': [11.546494, 4...  48.201280   11.546494
# 31   {'type': 'Point', 'coordinates': [8.701216, 50...  50.032976    8.701216
# 32   {'type': 'Point', 'coordinates': [8.580961, 50...  50.004863    8.580961
# 33   {'type': 'Point', 'coordinates': [13.393718, 5...  52.488331   13.393718
# 34   {'type': 'Point', 'coordinates': [13.345143, 5...  52.525092   13.345143
# 36   {'type': 'Point', 'coordinates': [-122.095612,...  37.389880 -122.095612
# 38   {'type': 'Point', 'coordinates': [11.53283, 48...  48.112800   11.532830
# 40   {'type': 'Point', 'coordinates': [13.38861, 52...  52.489700   13.388610
# 43   {'type': 'Point', 'coordinates': [11.558864, 4...  48.122346   11.558864
# 44   {'type': 'Point', 'coordinates': [13.419841, 5...  52.512249   13.419841
# 45   {'type': 'Point', 'coordinates': [9.9475619, 5...  53.544307    9.947562
# 46   {'type': 'Point', 'coordinates': [8.526666, 49...  49.922853    8.526666
# 48   {'type': 'Point', 'coordinates': [11.585092, 4...  48.181148   11.585092
# ..                                                 ...        ...         ...
# 339  {'type': 'Point', 'coordinates': [8.4649954, 4...  48.997425    8.464995
# 340  {'type': 'Point', 'coordinates': [11.6644864, ...  48.041847   11.664486
# 341  {'type': 'Point', 'coordinates': [6.8126313, 5...  51.498352    6.812631
# 343  {'type': 'Point', 'coordinates': [12.2568041, ...  51.656631   12.256804
# 344  {'type': 'Point', 'coordinates': [11.5697308, ...  48.136532   11.569731
# 347  {'type': 'Point', 'coordinates': [12.3419833, ...  51.328085   12.341983
# 348  {'type': 'Point', 'coordinates': [8.200653, 53...  53.149670    8.200653
# 349  {'type': 'Point', 'coordinates': [13.398504, 5...  52.494727   13.398504
# 352  {'type': 'Point', 'coordinates': [13.3117776, ...  52.478717   13.311778
# 353  {'type': 'Point', 'coordinates': [9.99862, 53....  53.550150    9.998620
# 354  {'type': 'Point', 'coordinates': [13.4089986, ...  52.532547   13.408999
# 355  {'type': 'Point', 'coordinates': [10.4183586, ...  53.261554   10.418359
# 358  {'type': 'Point', 'coordinates': [10.6976787, ...  53.835358   10.697679
# 359  {'type': 'Point', 'coordinates': [13.3813542, ...  52.527926   13.381354
# 360  {'type': 'Point', 'coordinates': [9.9762519, 5...  53.597305    9.976252
# 362  {'type': 'Point', 'coordinates': [13.7686212, ...  51.058005   13.768621
# 363  {'type': 'Point', 'coordinates': [13.7759644, ...  51.034362   13.775964
# 364  {'type': 'Point', 'coordinates': [11.6075086, ...  48.055441   11.607509
# 365  {'type': 'Point', 'coordinates': [13.0305666, ...  48.265012   13.030567
# 367  {'type': 'Point', 'coordinates': [10.0177531, ...  53.554390   10.017753
# 369  {'type': 'Point', 'coordinates': [9.0216057, 4...  48.256468    9.021606
# 370  {'type': 'Point', 'coordinates': [11.5353842, ...  48.381895   11.535384
# 371  {'type': 'Point', 'coordinates': [13.7850316, ...  51.126093   13.785032
# 372  {'type': 'Point', 'coordinates': [8.6084515, 4...  49.897475    8.608451
# 373  {'type': 'Point', 'coordinates': [8.5230082, 4...  49.507710    8.523008
# 374  {'type': 'Point', 'coordinates': [7.8048883, 5...  50.433334    7.804888
# 377  {'type': 'Point', 'coordinates': [9.1773043, 4...  48.781871    9.177304
# 379  {'type': 'Point', 'coordinates': [13.434474, 5...  52.494307   13.434474
# 381  {'type': 'Point', 'coordinates': [9.3962136, 5...  54.771291    9.396214
# 382  {'type': 'Point', 'coordinates': [10.1665152, ...  54.323738   10.166515
#
#     total_money_raised  founded_year  number_of_employees    category_code  \
# 1                  $5M        2006.0                  NaN      games_video
# 2                $555M        1998.0              28000.0           search
# 5                $248M        2004.0                300.0      advertising
# 8                   $0        2012.0                  8.0              web
# 10                  $0        2009.0                  7.0      games_video
# 12               €3.7M        2006.0                 15.0              web
# 13                  $0        2007.0                  3.0              web
# 17               €5.7M        2003.0                500.0  network_hosting
# 18              $17.5M        2003.0                200.0      games_video
# 19                  $0        2006.0                 76.0              web
# 20              £14.5M        2005.0                  NaN              web
# 21               €200k        2006.0                  5.0              web
# 22              €10.1M           NaN                  NaN      games_video
# 24                  $0        2006.0                 15.0           mobile
# 25                $35M        2008.0                100.0           design
# 26                  $0        2005.0                300.0              web
# 27                  $0        2007.0                  5.0         software
# 28                  $0           NaN                  NaN             None
# 31                  $0        1998.0                  NaN              web
# 32                  $0        1972.0                  NaN       enterprise
# 33                  $0        1999.0                800.0           mobile
# 34                  $0        2007.0                  6.0              web
# 36                  $0        2007.0                  NaN        ecommerce
# 38                  $0        2007.0                  3.0              web
# 40                $10M        2007.0                205.0        education
# 43                  $0        2007.0                  2.0      games_video
# 44              $6.26M        2006.0                  NaN              web
# 45                $40M        2002.0                  NaN      advertising
# 46                  $0        2008.0                  NaN              web
# 48                  $0        2007.0                  NaN           search
# ..                 ...           ...                  ...              ...
# 339                 $0        2009.0                  2.0              web
# 340               €10M           NaN                  NaN        cleantech
# 341             €7.44M        2006.0                  NaN        cleantech
# 343                 $0        1995.0                 70.0            other
# 344                 $0        1998.0                 55.0         software
# 347                 $0        1999.0                  NaN         software
# 348                 $0        2009.0                  2.0  network_hosting
# 349                $7M        2007.0                 43.0              web
# 352                 $0           NaN                  NaN             None
# 353                 $0        2008.0                  NaN      advertising
# 354                 $0        2001.0                200.0        ecommerce
# 355                 $0        2004.0                 40.0              web
# 358             $2.64M        2007.0                  NaN          biotech
# 359                €1M        2003.0                 25.0      advertising
# 360              €420M        2002.0                500.0      games_video
# 362                 $0           NaN                  NaN         software
# 363              €500k        2008.0                 12.0         software
# 364              €3.3M        2006.0                  NaN        cleantech
# 365             $2.71M        2006.0                  NaN         hardware
# 367                 $0        2006.0                  3.0              web
# 369                 $0           NaN                  NaN             None
# 370                 $0        1999.0                  NaN             None
# 371             $1.11M        2006.0                  NaN            other
# 372              €500k           NaN                  NaN         software
# 373                 $0        2003.0                  9.0         software
# 374                 $0           NaN               5000.0  network_hosting
# 377                 $0        2007.0                 25.0       enterprise
# 379                 $0        2007.0                  8.0      games_video
# 381                 $0           NaN                  NaN         software
# 382                 $0        2004.0                 35.0  network_hosting
#
#                                   description  \
# 1                      Fund raising for bands
# 2
# 5
# 8               Free Facebook video chat app.
# 10
# 12               Location Based Microblogging
# 13                                       None
# 17
# 18                        Casual Online Games
# 19                  Online Event Registration
# 20    Location-based reviews, recommendations
# 21
# 22                                       None
# 24                                       None
# 25          Online graphic design marketplace
# 26                      German Social Network
# 27            Free social publishing services
# 28                                       None
# 31               Global Technology Solutions
# 32              Enterprise Software Developer
# 33
# 34                                       None
# 36
# 38                                Social News
# 40                     Learn Languages Online
# 43                                       None
# 44                     Virtual world providor
# 45           Online advertising and marketing
# 46                       Microblogging System
# 48                                       None
# ..                                        ...
# 339                        Free Online Dating
# 340  Energy Management Solutions for Telecoms
# 341            Natural Product lead-discovery
# 343     Custom synthesis of organic chemicals
# 344         SaaS Solution for Book Publishers
# 347      software development and web testing
# 348                           Technology wiki
# 349         Personalized movie recommendation
# 352         Partner for Research and Practice
# 353                 Mobile Advertising Expert
# 354         International Comparison Shopping
# 355       German Comparison Shopping Platform
# 358                                  implants
# 359                      Online Web Analytics
# 360    developer and provider of online games
# 362
# 363              modular integration software
# 364            Electric Drive Trains for LEVs
# 365                Optical Sensor Technololgy
# 367                Social network for runners
# 369
# 370
# 371
# 372
# 373                    File Transfer Software
# 374          German Internet Service Provider
# 377    Sales Enablement, KM & RIA development
# 379     Schafkopf Community (German Cardgame)
# 381
# 382                      Web Hosting Services
#
#                                               overview  \
# 1    <p>SellaBand.com first launched in August 2006...
# 2    <p>Google provides search and advertising serv...
# 5    <p>Adknowledge is a digital marketing company ...
# 8    <p><a href="http://vive.me/" title="vive" rel=...
# 10   <p>alluc.org hosts a database of links to vide...
# 12   <p>Plazes allows you to find out what others a...
# 13   <p>MyNeighborhood is a local social network wi...
# 17   <p>XING is the social network for business pro...
# 18   <p>GameDuell – Bringing people together to hav...
# 19   <p>amiando is a pioneer in online event regist...
# 20   <p>Founded in 2006 by German entrepreneur, Ste...
# 21   <p>openPeople is a social networking community...
# 22   <p>iOpener provides and facilitates Real-time ...
# 24   <p>Qiro GmbH runs the mobile &amp; online comm...
# 25   <p>99designs is the world&#8217;s largest onli...
# 26   <p>Studivz.net is very similar to <a href="/co...
# 27   <p>doXtop is a state-of-the-art Web-publishing...
# 28   <p>Moconso connects companies with mobile serv...
# 31   <p>ADTECH is a global technology solutions com...
# 32   <p>As market leader in enterprise application ...
# 33   <p>Buongiorno is known in the worldwide mobile...
# 34    <p>acomo is a German social network service.</p>
# 36   <p>iliketotallyloveit.com is a social shopping...
# 38   <p>YiGG is a Social News Community focusing on...
# 40   <p>Babbel is the smart learning system for lan...
# 43   <p>Zankapfel is a competitive voting platform ...
# 44   <p>Metaversum develops and operates the 3D onl...
# 45   <p><a href="http://www.undertone.com" title="U...
# 46   <p>Asaph is a microblogging system, that allow...
# 48   <p>andUNITE adds human knowledge to search res...
# ..                                                 ...
# 339  <p>Find&amp;Smile introduces Free Online Datin...
# 340  <p>Headquartered near Munich, P21 develops, pr...
# 341  <p>InterMed Discovery is an emerging world cla...
# 343  <p>Organica is a manufacturer of high quality ...
# 344  <p>GRIN Publishing is an online based publishi...
# 347  <p>Custom software products and telecommunicat...
# 348  <p>youserbase is a technology knowledge platfo...
# 349  <p>Moviepilot is a home for upcoming movies an...
# 352  <p>Knowledge, information and quality â€“ thes...
# 353  <p>apprupt is the mobile advertising expert fo...
# 354  <p>The Idealo Internet GmbH, located in Berlin...
# 355  <p>The German price comparison site &#8220;Pre...
# 358  <p>Microstim GmbH develops a tissue and functi...
# 359  <p>WebtrekkÂ´s Q3 web analytics solution enabl...
# 360  <p>Bigpoint.com is the biggest game portal in ...
# 362  <p>sim4tec provides comprehensive simulation s...
# 363  <p>ubigrate is specialised powerful integratio...
# 364  <p>Clean Mobile AG was founded in 2006 by the ...
# 365  <p>ISIS sentronics GmbH, which creates industr...
# 367  <p>jogmap is a German  online community for ru...
# 369  <p>Centrotherm photovoltaics provides its cust...
# 370  <p>GP Solar GmbH is decisively involved in the...
# 371  <p>HiperScan is the expert in light scanning t...
# 372  <p>Liquiverse is a young software company edit...
# 373  <p>Pro2col specialise in the supply and integr...
# 374  <p>United Internet AG is a German Internet ser...
# 377  <p>BizSphere AG is a software and consulting c...
# 379  <p>Sauspiel is the largest web community aroun...
# 381  <p>Metasonic (formerly jCOM1) was set up in 19...
# 382  <p>AwardSpace is a Web Hosting Company offerin...
#
#                                               tag_list
# 1                      musicmonetizatoin, music, bands
# 2    search, gmail, blogger, find, information, you...
# 5    advertising, cpc, adstation, cubics, bidsystem...
# 8
# 10                        video, piracy, videodatabase
# 12   places, maps, social, community, location, geo...
# 13                                                None
# 17   socialnetworking, contacts, professionalnetwor...
# 18   games, social, cross-platform, berlin, fun, go...
# 19   events, event-community, , ticketing, event-re...
# 20
# 21
# 22
# 24
# 25   graphic-design, crowdsourcing, online-marketpl...
# 26         socialnetwork, germany, berlin, holtzbrinck
# 27   publishing, social-publishing, publishing-hous...
# 28                                                None
# 31   adserving, technology, solutions, ad-platform,...
# 32
# 33   mobile, vas, community, social-networking, con...
# 34
# 36   social-shopping, web-2-0, e-commerce, recommen...
# 38   yigg, social-news, news, nachrichten, nachrich...
# 40   online-language-learning, learn-english, apps,...
# 43              zankapfel, competition, gaming, voting
# 44                                           metaverse
# 45   digital-advertising, online-advertising, digit...
# 46                                 microblogging, blog
# 48   andunite, social-search, search-term, search-t...
# ..                                                 ...
# 339  dating, free, online-dating, dating-site, free...
# 340
# 341
# 343  organic-chemistry, custom-synthesis, fine-chem...
# 344  publishing, academic, book, ebook, print-on-de...
# 347  software-development, web-testing, web-testing...
# 348                           germany, oldenburg, wiki
# 349  media, film, cinema, tv, dvd, stars, entertain...
# 352
# 353
# 354  comparison, shopping, flights, travel, electro...
# 355  comparison-shopping, product-reviews, preisver...
# 358
# 359  online-analytics, optimization, real-time-anal...
# 360  online-games, browser-games, browsergames, bro...
# 362
# 363
# 364
# 365
# 367        jogging, running, community, social-network
# 369
# 370                                               None
# 371
# 372
# 373  managed-file-transfer, large-file-transfer, fa...
# 374  germany, isp, internet-service-providers, hosting
# 377  sales, marketing, sales-enablement, knowledge-...
# 379  schafkopf, online-schafkopf, gaming, community...
# 381
# 382  free-webhosting, webhosting, vps, dedicated-se...
#
# [277 rows x 13 columns]

# %%
germany.sort_values(by=['founded_year'], ascending=False, inplace=True)
germany
# Out:
#                         name            city  \
# 8                      headr          Berlin
# 196                    fruux        Muenster
# 305                 printium         Potsdam
# 325               expertnews         Hamburg
# 348               youserbase       Oldenburg
# 339             FindandSmile       Karlsruhe
# 338                    scoyo         Hamburg
# 279                     yiid        Weinheim
# 299              Webteilchen          Berlin
# 283  Gate 53|10 Technologies         Hamburg
# 264             betterchange         GieÃŸen
# 10                     alluc     Norderstedt
# 314                 makandra        Augsburg
# 304                   quoobs          Berlin
# 226                FutureTap         Seefeld
# 222                   TRIBAX          Berlin
# 73                    Jupidi         Hamburg
# 144        FashionFreax GmbH   WÃ¤chtersbach
# 294              Jakun Media          Berlin
# 307                   kinkon  Kaiserslautern
# 291                   djacap     Duesseldorf
# 280                  tolingo         Hamburg
# 287                  Tamundo          Berlin
# 284                 PickPark        Wurzberg
# 282            SuperSwitcher          Berlin
# 228                     CtoJ         Cologne
# 134                  want2do          Berlin
# 235            Kaeuferportal          Berlin
# 248            Digital Bloom          Munich
# 106                   plista          Berlin
# ..                       ...             ...
# 75                  SpellBoy         Hamburg
# 77                 Cittadino     DÃ¼sseldorf
# 80                 LaterLoop          Berlin
# 81                    NOTXOR          Munich
# 82             link-together          Berlin
# 102            mental images          Berlin
# 139                 Avengina        Chemnitz
# 209            shopotainment          Berlin
# 212           ROCKET RENTALS          Berlin
# 229                  Conject          Munich
# 238                  Innotek       Weinstadt
# 252               match2blue           Mainz
# 253                 NovaStor         Hamburg
# 256                      BMW         München
# 275                 Papp-Art     DÃ¼sseldorf
# 302                  Novaled         Dresden
# 313    Nanotron Technologies          Berlin
# 315                Spirofrog         München
# 317                    doctr         Potsdam
# 318               kontoblick          Munich
# 326      Winbox Technologies      Furtwangen
# 329       Bubbles and Beyond         Leipzig
# 332               EcoIntense          Berlin
# 340                      P21          Munich
# 352                 Springer          Berlin
# 362                  sim4tec         Dresden
# 369              Centrotherm
# 372               Liquiverse       Darmstadt
# 374          United Internet        Montabur
# 381                Metasonic
#
#                                                offices  \
# 8    [{'description': '', 'address1': 'Ritterstr. 1...
# 196  [{'description': '', 'address1': '', 'address2...
# 305  [{'description': 'HQ', 'address1': 'Behlertstr...
# 325  [{'description': '', 'address1': '', 'address2...
# 348  [{'description': 'Headquarters', 'address1': '...
# 339  [{'description': '705 West GmbH', 'address1': ...
# 338  [{'description': 'scoyo GmbH', 'address1': 'Gr...
# 279  [{'description': 'yiid', 'address1': 'Grundelb...
# 299  [{'description': 'Webteilchen Berlin', 'addres...
# 283  [{'description': 'Headquarters', 'address1': '...
# 264  [{'description': '', 'address1': 'Riegelpfad 6...
# 10   [{'description': '', 'address1': 'Stormarnstra...
# 314  [{'description': 'World Headquarter', 'address...
# 304  [{'description': 'Headquarter', 'address1': 'S...
# 226  [{'description': 'FutureTap', 'address1': 'See...
# 222  [{'description': 'Head Office', 'address1': 'L...
# 73   [{'description': 'Jupidi GmbH', 'address1': 'K...
# 144  [{'description': '', 'address1': 'Bleichgarten...
# 294  [{'description': 'Jakun Media', 'address1': 'S...
# 307  [{'description': 'Headquarter', 'address1': 'E...
# 291  [{'description': 'djacap - EU', 'address1': 'H...
# 280  [{'description': 'Office', 'address1': 'Planck...
# 287  [{'description': '', 'address1': 'Oranienburge...
# 284  [{'description': 'HQ', 'address1': '', 'addres...
# 282  [{'description': '', 'address1': 'Melanchthons...
# 228  [{'description': 'CtoJ', 'address1': 'Im Media...
# 134  [{'description': 'Berlin Office', 'address1': ...
# 235  [{'description': 'Headquarters', 'address1': '...
# 248  [{'description': 'Headquarter', 'address1': 'R...
# 106  [{'description': 'Headquarter', 'address1': 'T...
# ..                                                 ...
# 75   [{'description': '', 'address1': '', 'address2...
# 77   [{'description': None, 'address1': 'Hammer Dor...
# 80   [{'description': None, 'address1': 'Friedrichs...
# 81   [{'description': None, 'address1': 'Lothstrass...
# 82   [{'description': '', 'address1': 'Prenzlauer B...
# 102  [{'description': 'mental images, Inc.', 'addre...
# 139  [{'description': '', 'address1': '', 'address2...
# 209  [{'description': 'shopotainment headquarter', ...
# 212  [{'description': 'Headquarters', 'address1': '...
# 229  [{'description': 'Headquarters', 'address1': '...
# 238  [{'description': '', 'address1': 'Werkstrasse ...
# 252  [{'description': 'North America Office', 'addr...
# 253  [{'description': 'NovaStor', 'address1': '2920...
# 256  [{'description': '', 'address1': 'Petuelring 1...
# 275  [{'description': 'Head', 'address1': '', 'addr...
# 302  [{'description': None, 'address1': None, 'addr...
# 313  [{'description': 'Nanotron Technologies', 'add...
# 315  [{'description': 'Munich HQ', 'address1': 'Kuf...
# 317  [{'description': '', 'address1': 'Bertha-von-S...
# 318  [{'description': '', 'address1': '', 'address2...
# 326  [{'description': 'Office Furtwagen (HQ)', 'add...
# 329  [{'description': '', 'address1': 'Karl-Heine-S...
# 332  [{'description': 'EcoIntense GmbH', 'address1'...
# 340  [{'description': '', 'address1': 'Eugen-SÃ¤nge...
# 352  [{'description': '', 'address1': 'Heidelberger...
# 362  [{'description': '', 'address1': 'Arnoldstr. 1...
# 369  [{'description': '', 'address1': 'Johannes-Sch...
# 372  [{'description': '', 'address1': 'Goethestrass...
# 374  [{'description': 'HQ', 'address1': 'Elgendorfe...
# 381  [{'description': '', 'address1': 'Lilienthalst...
#
#                                                   site        lat        lng  \
# 8    {'type': 'Point', 'coordinates': [13.4109071, ...  52.501345  13.410907
# 196  {'type': 'Point', 'coordinates': [7.6267552, 5...  51.963009   7.626755
# 305  {'type': 'Point', 'coordinates': [13.0673441, ...  52.405558  13.067344
# 325  {'type': 'Point', 'coordinates': [9.9819779, 5...  53.568810   9.981978
# 348  {'type': 'Point', 'coordinates': [8.200653, 53...  53.149670   8.200653
# 339  {'type': 'Point', 'coordinates': [8.4649954, 4...  48.997425   8.464995
# 338  {'type': 'Point', 'coordinates': [9.9490139, 5...  53.562270   9.949014
# 279  {'type': 'Point', 'coordinates': [8.6759098, 4...  49.550756   8.675910
# 299  {'type': 'Point', 'coordinates': [13.6281888, ...  52.529674  13.628189
# 283  {'type': 'Point', 'coordinates': [10.0184565, ...  53.573640  10.018456
# 264  {'type': 'Point', 'coordinates': [8.675371, 50...  50.577722   8.675371
# 10   {'type': 'Point', 'coordinates': [10.023246, 5...  53.707739  10.023246
# 314  {'type': 'Point', 'coordinates': [10.9059804, ...  48.340029  10.905980
# 304  {'type': 'Point', 'coordinates': [13.4663753, ...  52.518990  13.466375
# 226  {'type': 'Point', 'coordinates': [11.1974291, ...  48.038781  11.197429
# 222  {'type': 'Point', 'coordinates': [13.3922487, ...  52.527310  13.392249
# 73   {'type': 'Point', 'coordinates': [9.966419, 53...  53.561185   9.966419
# 144  {'type': 'Point', 'coordinates': [13.37402, 52...  52.537588  13.374020
# 294  {'type': 'Point', 'coordinates': [10.1251434, ...  53.584935  10.125143
# 307  {'type': 'Point', 'coordinates': [7.771808, 49...  49.439304   7.771808
# 291  {'type': 'Point', 'coordinates': [6.770176, 51...  51.213240   6.770176
# 280  {'type': 'Point', 'coordinates': [9.9255806, 5...  53.561734   9.925581
# 287  {'type': 'Point', 'coordinates': [13.3913657, ...  52.525354  13.391366
# 284  {'type': 'Point', 'coordinates': [9.927489, 49...  49.794256   9.927489
# 282  {'type': 'Point', 'coordinates': [13.3541667, ...  52.521099  13.354167
# 228  {'type': 'Point', 'coordinates': [6.9410409, 5...  50.947139   6.941041
# 134  {'type': 'Point', 'coordinates': [13.465981, 5...  52.510284  13.465981
# 235  {'type': 'Point', 'coordinates': [13.3936665, ...  52.512337  13.393667
# 248  {'type': 'Point', 'coordinates': [11.5853709, ...  48.121073  11.585371
# 106  {'type': 'Point', 'coordinates': [13.4124563, ...  52.528361  13.412456
# ..                                                 ...        ...        ...
# 75   {'type': 'Point', 'coordinates': [9.992196, 53...  53.553407   9.992196
# 77   {'type': 'Point', 'coordinates': [6.750537, 51...  51.211513   6.750537
# 80   {'type': 'Point', 'coordinates': [13.434717, 5...  52.521066  13.434717
# 81   {'type': 'Point', 'coordinates': [11.557857, 4...  48.156424  11.557857
# 82   {'type': 'Point', 'coordinates': [13.420498, 5...  52.528670  13.420498
# 102  {'type': 'Point', 'coordinates': [13.327876, 5...  52.505675  13.327876
# 139  {'type': 'Point', 'coordinates': [12.924694, 5...  50.832503  12.924694
# 209  {'type': 'Point', 'coordinates': [13.295232, 5...  52.450364  13.295232
# 212  {'type': 'Point', 'coordinates': [13.4569337, ...  52.513075  13.456934
# 229  {'type': 'Point', 'coordinates': [11.5485907, ...  48.122962  11.548591
# 238  {'type': 'Point', 'coordinates': [9.3755648, 4...  48.815888   9.375565
# 252  {'type': 'Point', 'coordinates': [8.7620233, 5...  50.130735   8.762023
# 253  {'type': 'Point', 'coordinates': [10.0824355, ...  53.573417  10.082436
# 256  {'type': 'Point', 'coordinates': [11.56134, 48...  48.176900  11.561340
# 275  {'type': 'Point', 'coordinates': [6.7190874, 5...  51.233068   6.719087
# 302  {'type': 'Point', 'coordinates': [13.7372621, ...  51.050409  13.737262
# 313  {'type': 'Point', 'coordinates': [13.3278512, ...  52.524259  13.327851
# 315  {'type': 'Point', 'coordinates': [11.6019644, ...  48.149357  11.601964
# 317  {'type': 'Point', 'coordinates': [13.0627199, ...  52.406999  13.062720
# 318  {'type': 'Point', 'coordinates': [11.6120973, ...  48.123408  11.612097
# 326  {'type': 'Point', 'coordinates': [8.2054054, 4...  48.050514   8.205405
# 329  {'type': 'Point', 'coordinates': [12.3274318, ...  51.329674  12.327432
# 332  {'type': 'Point', 'coordinates': [13.5330535, ...  52.457152  13.533053
# 340  {'type': 'Point', 'coordinates': [11.6644864, ...  48.041847  11.664486
# 352  {'type': 'Point', 'coordinates': [13.3117776, ...  52.478717  13.311778
# 362  {'type': 'Point', 'coordinates': [13.7686212, ...  51.058005  13.768621
# 369  {'type': 'Point', 'coordinates': [9.0216057, 4...  48.256468   9.021606
# 372  {'type': 'Point', 'coordinates': [8.6084515, 4...  49.897475   8.608451
# 374  {'type': 'Point', 'coordinates': [7.8048883, 5...  50.433334   7.804888
# 381  {'type': 'Point', 'coordinates': [9.3962136, 5...  54.771291   9.396214
#
#     total_money_raised  founded_year  number_of_employees    category_code  \
# 8                   $0        2012.0                  8.0              web
# 196                 $0        2010.0                  NaN              web
# 305                 $0        2009.0                  3.0       enterprise
# 325                 $0        2009.0                  1.0              web
# 348                 $0        2009.0                  2.0  network_hosting
# 339                 $0        2009.0                  2.0              web
# 338                 $0        2009.0                 13.0      games_video
# 279                 $0        2009.0                  9.0              web
# 299                 $0        2009.0                  2.0              web
# 283              €141k        2009.0                  4.0              web
# 264                 $0        2009.0                  NaN       consulting
# 10                  $0        2009.0                  7.0      games_video
# 314                 $0        2009.0                  8.0         software
# 304                 $0        2009.0                  3.0              web
# 226                 $0        2008.0                  1.0         software
# 222                 $0        2008.0                 12.0  network_hosting
# 73                  $0        2008.0                  3.0              web
# 144                 $0        2008.0                  NaN              web
# 294                 $0        2008.0                  4.0      games_video
# 307              €750k        2008.0                 10.0              web
# 291                 $0        2008.0                  4.0       consulting
# 280              $600k        2008.0                 40.0        messaging
# 287                 $0        2008.0                 28.0        ecommerce
# 284               €10k        2008.0                  3.0         software
# 282                 $0        2008.0                  NaN              web
# 228                 $0        2008.0                  4.0       consulting
# 134                 $0        2008.0                  4.0              web
# 235                 $0        2008.0                 21.0       enterprise
# 248                 $0        2008.0                  5.0        ecommerce
# 106              $3.8M        2008.0                100.0      advertising
# ..                 ...           ...                  ...              ...
# 75                  $0           NaN                  NaN             None
# 77                  $0           NaN                  NaN             None
# 80                  $0           NaN                  1.0           mobile
# 81                  $0           NaN                  NaN         software
# 82                  $0           NaN                  NaN              web
# 102                 $0           NaN                  NaN         software
# 139                 $0           NaN                  NaN         software
# 209                 $0           NaN                  3.0        ecommerce
# 212                 $0           NaN                  7.0      advertising
# 229                $5M           NaN                  NaN         software
# 238                 $0           NaN                  NaN         software
# 252                 $0           NaN                  NaN           mobile
# 253                 $0           NaN                  NaN         software
# 256                 $0           NaN                  NaN       automotive
# 275                 $0           NaN                  NaN            other
# 302             €26.2M           NaN                  NaN        cleantech
# 313             $17.4M           NaN                  NaN           mobile
# 315                 $0           NaN                  NaN             None
# 317                 $0           NaN                 10.0       enterprise
# 318                 $0           NaN                 10.0              web
# 326             $1.56M           NaN                  NaN         hardware
# 329              $2.4M           NaN                  NaN          biotech
# 332              $909k           NaN                  NaN         software
# 340               €10M           NaN                  NaN        cleantech
# 352                 $0           NaN                  NaN             None
# 362                 $0           NaN                  NaN         software
# 369                 $0           NaN                  NaN             None
# 372              €500k           NaN                  NaN         software
# 374                 $0           NaN               5000.0  network_hosting
# 381                 $0           NaN                  NaN         software
#
#                                   description  \
# 8               Free Facebook video chat app.
# 196        Syncs Contacts, calender and tasks
# 305                Global Publishing Platform
# 325
# 348                           Technology wiki
# 339                        Free Online Dating
# 338  gamebased learning platform for children
# 279     Social Media Monitor and Identity Hub
# 299           Web Services & Online Marketing
# 283                     Enhanced web browsing
# 264                         Change management
# 10
# 314        Ruby on Rails Web Development Shop
# 304            social, local, mobile services
# 226                         Smart iPhone Apps
# 222         Social Network Community Provider
# 73                             Dating Website
# 144                    Fashion Social network
# 294      content scout & aggregator, licensor
# 307                 Web Security for Families
# 291                IT Consulting & Management
# 280                 online translation agency
# 287       Social Marketplace for Collectibles
# 284                Social business networking
# 282          Online tariff comparison service
# 228                        Software Migration
# 134                     German Social Network
# 235                                      None
# 248
# 106    recommendation and advertising network
# ..                                        ...
# 75                                       None
# 77                                       None
# 80                                       None
# 81                                       None
# 82                                       None
# 102                                      None
# 139                                      None
# 209                                      None
# 212                                      None
# 229                                      None
# 238        Open source desktop virtualization
# 252                  Mobile Ambient Awareness
# 253                     availability software
# 256
# 275                                PappmÃ¶bel
# 302                         OLED manufacturer
# 313                         wireless products
# 315                                      None
# 317       Secure doctor patient communication
# 318    German Online personal finance service
# 326                  OEM technology solutions
# 329                        Technology company
# 332          Environmental Software Developer
# 340  Energy Management Solutions for Telecoms
# 352         Partner for Research and Practice
# 362
# 369
# 372
# 374          German Internet Service Provider
# 381
#
#                                               overview  \
# 8    <p><a href="http://vive.me/" title="vive" rel=...
# 196  <p>fruux solves the problem of working with co...
# 305  <p>printium&#8217;s vision is to provide all p...
# 325  <p>expertnews.me - follow news from experts yo...
# 348  <p>youserbase is a technology knowledge platfo...
# 339  <p>Find&amp;Smile introduces Free Online Datin...
# 338  <p>scoyo is an innovative online learning plat...
# 279  <p>Your Internet ID has the only flexible Like...
# 299  <p>A German agency for online marketing, Searc...
# 283  <p>At GATE 53|10 we develop and market Fytch, ...
# 264  <p>betterchange is a consultancy specialized i...
# 10   <p>alluc.org hosts a database of links to vide...
# 314  <p>About makandra GmbH</p>\n\n<p>The makandra ...
# 304  <p>quoobs creates sticky services. quoobs is a...
# 226  <p>FutureTap is a developer of innovative iPho...
# 222  <p>TRIBAX is an experienced provider of Web 2....
# 73   <p>Jupidi is launching a web and mobile servic...
# 144  <p>fashionfreax is a fashion and design social...
# 294  <p>Jakun Media, based in Berlin (Germany), wor...
# 307  <p>kinkon.de makes the net a secure place for ...
# 291  <p>djacap Inc. | lean development &amp; busine...
# 280  <p>By combining expert knowledge and innovativ...
# 287  <p>Located in Berlin, Germany, Tamundo is a fa...
# 284  <p>PickPark offers businesses a chance to get ...
# 282  <p>SuperSwitcher provides a free, impartial on...
# 228  <p>CtoJ is a service provider that focuses on ...
# 134  <p>want2do.de is a German social network dedic...
# 235  <p>Kaeuferportal is a B2B Lead Generation plat...
# 248  <p>With the service of digitalbloom, now every...
# 106  <p>plista is a pioneer when it comes to innova...
# ..                                                 ...
# 75                                                None
# 77   <p>Cittadino focuses on digital signage, a con...
# 80   <p>LaterLoop is a tool that allows users to sa...
# 81   <p><a href="http://notxor.com/" title="NOTXOR"...
# 82
# 102  <p>mental images provides software rendering a...
# 139  <p>Avengina is a realtime 3D graphics engine a...
# 209  <p>Show what you&#8217;ve got, find what you l...
# 212  <p>ROCKET RENTALS is a Web solutions agency wh...
# 229  <p>Conject believes that real estate processes...
# 238  <p>Innotek, a Stuttgart, Germany provider of o...
# 252  <p>match2blue is a German-American technology ...
# 253  <p><a href="http://www.NovaStor.com/" title="N...
# 256  <p>Bayerische Motoren Werke AG (BMW), (English...
# 275  <p>Papp-Art makes furniture out of recycled ca...
# 302  <p>Novaled AG is a world-class technology prov...
# 313  <p>Nanotron Technologies is a leader in the de...
# 315  <p>Spirofrog is not an ordinary/internship pla...
# 317  <p>doctr.com builds secure doctor to patient a...
# 318  <p>kontoblick is the first and only web app fo...
# 326  <p>Winbox Technologies is a leading provider o...
# 329  <p>bubbles &amp; beyond is a technology compan...
# 332  <p>EcoIntense provides environmental managemen...
# 340  <p>Headquartered near Munich, P21 develops, pr...
# 352  <p>Knowledge, information and quality â€“ thes...
# 362  <p>sim4tec provides comprehensive simulation s...
# 369  <p>Centrotherm photovoltaics provides its cust...
# 372  <p>Liquiverse is a young software company edit...
# 374  <p>United Internet AG is a German Internet ser...
# 381  <p>Metasonic (formerly jCOM1) was set up in 19...
#
#                                               tag_list
# 8
# 196  sync, synchronize, contacts, calendars, events...
# 305    print, publishing, community, global, directory
# 325                         news, twitter, rss, reader
# 348                           germany, oldenburg, wiki
# 339  dating, free, online-dating, dating-site, free...
# 338  e-learning, gamebasedlearning, seriousgames, e...
# 279  openweb, openid, dataportability, microformats...
# 299  online-marketing, web-service, web-services, p...
# 283  affiliate-aggregation, content-monetization, a...
# 264  consultancy, change, management, change-manage...
# 10                        video, piracy, videodatabase
# 314  filepanic, ruby-on-rails, webapplications, saa...
# 304  mobile, web, location-based, context-based, be...
# 226  iphone, apple, app-store, gps, poi, point-of-i...
# 222   tribax, social-network, communities, white-label
# 73
# 144  fashion, community, trends, styles, outfits, m...
# 294  germany, production, distribution, licensing, ...
# 307                   parental-control, secure-surfing
# 291  innovation, consulting, solutions, ventures, e...
# 280                   language, ecommerce, translation
# 287  marketplace, collectibles, unique-items, germa...
# 284  pickpark-pick-park-advertising-social-business...
# 282  gas, electricity, power, utility, comparison, ...
# 228                                          migration
# 134                      future, to-do, social-network
# 235                 b2b, lead-generation, germany, sme
# 248  art, gallery, design, wallpaper, visuals, fram...
# 106  content-recommendation, content-discovery, rec...
# ..                                                 ...
# 75                                                None
# 77                                     digital-signage
# 80                 reading, send-to-mobile, app-engine
# 81                                             mac-web
# 82
# 102                      software, graphics, animators
# 139                           3d-graphics, java-applet
# 209                           shopping, recommendation
# 212                    twitter, marketing, soccer, web
# 229
# 238
# 252  mobile-location, mobile-social-networking, rea...
# 253  backup-software, windows-backup-software, best...
# 256
# 275        pappmbel, mbel-aus-pappe, design, workshops
# 302
# 313
# 315
# 317  health, medicine, healthcare, video, videochat...
# 318                             banking, germany, hbci
# 326
# 329
# 332
# 340
# 352
# 362
# 369
# 372
# 374  germany, isp, internet-service-providers, hosting
# 381
#
# [277 rows x 13 columns]

# %%
germany.to_csv('germany.csv')

# %%
germany.to_json('germany.json', orient='records')

# %%
display(df_clean.shape)
df_clean.head()

# %%
# Remove offices with unexisting lat,lng or both lat and lng data
#df_clean.dropna(axis=0, inplace=True)

# mongoimport --db companies --collection first_office --jsonArray ./data/oficinas.json
df_clean.to_json('./data/oficinas.json', orient="records")

# %%
#https://docs.mongodb.com/manual/reference/operator/query/near/index.html
def findNear(geopoint, radio_max_meters=1000):
    return db.first_office.find({
        "oficina_principal": {
         "$near": {
           "$geometry": geopoint,
           "$maxDistance": radio_max_meters,
         }
       }
    })


# https://developers.google.com/maps/documentation/geocoding/intro
park_avenue_con_21_street = {
    "type":"Point",
    "coordinates":[-73.987308,40.738935]
}
radio_max_meters = 10000
num_offices = findNear(park_avenue_con_21_street, radio_max_meters).count()

print(f"Hay {num_offices} oficinas cerca a {radio_max_meters} metros")
print("La mas cercana es")
print(list(findNear(park_avenue_con_21_street, radio_max_meters).limit(1)))

# %%
pd.DataFrame(findNear(park_avenue_con_21_street, 5000)).to_csv("./data/geoesp.csv")
